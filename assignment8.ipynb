# %% [markdown]
# <a href="https://colab.research.google.com/github/iseve001/CSC221_iseve001/blob/main/assignment8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
message = input("Anything you type I will repeat - ")
print(message)
name = input("Hello, what's your name? - ")
age = input(f"Hello {name}! How old are you? - ")
age = int(age)
age >= 18
height = input("Welcome! How tall are you? - ")
height = int(height)
if height >= 50:
  print("You're tall enough to ride, climb aboard!")
else:
  print("Sorry, you are not tall enough to ride!")
number = input("Enter a # and I will check if it's even or odd. - ")
number = int(number)
if number % 2 == 0:
  print(f"{number} is even!")
else:
  print(f"{number} is odd!")
rental = input("Hello, what type of vehicle would you like to rent? - ")
print(f"Let me check if we have any {rental}s available.")
ten  = input("Enter a # and I will check if it is a multiple of 10. - ")
ten = int(ten)
if ten % 10 == 0:
  print(f"{ten} is divisible by 10!")
else:
  print(f"{ten} is not divisible by 10!")
currentnum = 1
while currentnum <= 5:
  print(currentnum)
  currentnum += 1
prompt = "Anything you type I will repeat. "
prompt += "Enter 'quit' to end the program. "
message = ""
while message != 'quit':
  message = input(prompt)
  if message != 'quit':
    print(message)
active = True
while active:
  message = input(prompt)
  if message == 'quit':
    active = False
  else:
    print(message)
prompt = "Please enter the name of a city you have visited."
prompt += "(Enter 'quit' when finsihed.) - "
while True:
  city = input(prompt)
  if city == 'quit':
    break
  else:
    print(f"I want to go to {city.title()}!")
currentnum = 0
while currentnum < 10:
 currentnum += 1
 if currentnum % 2 == 0:
  continue
 print(currentnum)
x = 1
age = input("How old are you? (Input quit to cancel) - ")
if age == 'quit':
  print("Purchase cancelled.")
age = int(age)
if age <= 2:
  print("You get free admission, welcome!")
else:
  if age <= 11:
    print("That will be $10, please.")
  else:
    print("That will be $15, please")
unconfirmed_users = ['ian', 'ned', 'joe']
confirmed_users = []
while unconfirmed_users:
  current_user = unconfirmed_users.pop()
  print(f"Verifying user: {current_user.title()}")
  confirmed_users.append(current_user)
print("The following users have been confirmed:")
for confirmed_user in confirmed_users:
 print(confirmed_user.title())
foods = ['tacos', 'pizza', 'burgers', 'fish', 'pizza', 'steak', 'pizza']
print(foods)
while 'pizza' in foods:
 foods.remove('pizza')
print(foods)
sandwich_orders = 'italian, meatball, chicken parmesan'
finished_sandwiches= ['']
print("Italian sub is ready!")
print("Meatball sub is ready!")
print("Chicken Parmesan  sub is ready!")
#calcnum = input("Welcome to Ian's calculator. Please enter a starting number. - ")

#x = 0
#answer = 0
#addnum = 0
#operator = input("What operator would you like to use? ")
#if(operator == '+'):
#  addnum = input("What would you like to add? ")
#  x + addnum == answer
#  print({addnum}+{answer})
# Out:
# Anything you type I will repeat - no you wont
# no you wont
# Hello, what's your name? - Ian
# Hello Ian! How old are you? - 21
# Welcome! How tall are you? - 60
# You're tall enough to ride, climb aboard!
# Enter a # and I will check if it's even or odd. - 20
# 20 is even!
# Hello, what type of vehicle would you like to rent? - car
# Let me check if we have any cars available.
# Enter a # and I will check if it is a multiple of 10. - 20
# 20 is divisible by 10!
# 1
# 2
# 3
# 4
# 5
# Anything you type I will repeat. Enter 'quit' to end the program. no you wonty
# no you wonty
# Anything you type I will repeat. Enter 'quit' to end the program. quit
# Anything you type I will repeat. Enter 'quit' to end the program. quit
# Please enter the name of a city you have visited.(Enter 'quit' when finsihed.) - nyc
# I want to go to Nyc!
# Please enter the name of a city you have visited.(Enter 'quit' when finsihed.) - quit
# 1
# 3
# 5
# 7
# 9
# How old are you? (Input quit to cancel) - 21
# ...
