# %%
enemy_0 = {'color':'blue', 'points':5}
print(enemy_0['color'])
print(enemy_0['points'])
new_points = enemy_0['points']
print(f"+{new_points} points!")
print(enemy_0)
enemy_0['x_position'] = 0
enemy_0['y_position'] = 25
print(enemy_0)
enemy_0 = {'color':'red'}
print(f"The enemy is wearing a {enemy_0['color']} shirt.")
enemy_0 = {'x_position':0,'y_position':25,'speed':'medium'}
print(f"Original X position: {enemy_0['x_position']}")
if enemy_0['speed'] == 'slow':
  x_increment = 1
elif enemy_0['speed'] == 'medium':
  x_increment = 2
else:
  x_increment = 3
enemy_0['x_position'] = enemy_0['x_position'] + x_increment
print(f"New X position: {enemy_0['x_position']}")
enemy_0 = {'color':'blue', 'points':5}
del enemy_0['points']
print(enemy_0)

fav_food = {
 'joe': 'tacos',
 'meghan': 'pizza',
 'aidan': 'pasta',
 'poe': 'soup',
 }
food = fav_food['meghan'].title()
print(f"Meghan loves {food}.")

enemy_0 = {'color': 'blue', 'speed': 'slow'}
point_value = enemy_0.get('points', '0 points.')
print(point_value)

ian = {
    'first_name':'ian',
    'last_name':'sever',
    'age':'20',
    'city':'plattsburgh'
  }
print(ian['first_name'])
print(ian['last_name'])
print(ian['age'])
print(ian['city'])

fav_num = {'joe':'1',
           'jack':'2',
           'john':'3',
           'jason':'4',
           'jalen':'5',
           }
print(fav_num)

jump  = {'word':'jump',
        'definition':'controls the flow of code and alter the normal sequential execution of statements'}
run = {'word':'run',
       'definition':'executing the code'}
ide = {'word':'ide',
       'definition':'a software application that provides a comprehensive set of features'}
loop = {'word':'loop',
        'definition':'repeating something over and over until a particular condition is satisfied'}
compiler = {'word':'compiler',
            'definition':'software that translates Python code from human language form into machine code that can be executed directly by a computer'}
revision = {'word':'revision',
            'definition':'any change in made in any form to a project'}
boolean = {'word':'boolean',
           'definition':'a logic that denotes true/false'}
commit = {'word':'commit',
          'definition':'to overwrite a previous revision with changes made in a working copy'}
merge = {'word':'merge',
         'definition':'an operation in which two sets of changes are applied to a file or set of files'}
index = {'word':'index',
         'definition':'the location of specific value stored in Python lists or tuples'}
print(jump['word'],"-",jump['definition'])
print(run['word'],"-",run['definition'])
print(loop['word'],"-",loop['definition'])
print(ide['word'],"-",ide['definition'])
print(compiler['word'],"-",compiler['definition'])
print(revision['word'],"-",revision['definition'])
print(boolean['word'],"-",boolean['definition'])
print(commit['word'],"-",commit['definition'])
print(merge['word'],"-",merge['definition'])
print(index['word'],"-",index['definition'])
user_0 = {
    'username':'iseve001',
    'first':'ian',
    'last':'sever'
}
for key, value in user_0.items():
 print(f"\nKey: {key}")
 print(f"Value: {value}")
food = fav_food['poe'].title()
for name in fav_food.keys():
 print(f"Hi {name.title()}.")
 print(f"\t{name.title()}, I see you love {food}!")
print("The following foods have been mentioned:",fav_food)
cities = {'NYC':'is in America, has a population of 8.5M, and the first pizzeria in the US was opened there',
       'TYO': 'is in Japan, has a population of 14M, and is the biggest city in the world',
       'IST' : 'is in Turkey, has a population of 16M, and is the one and only transcontinental city in the world.',
       }
#for citie in cities:(
#    print(f"{citie}"),
#)
for key, value in cities.items():
    print(key, value)
# Out:
# blue
# 5
# +5 points!
# {'color': 'blue', 'points': 5}
# {'color': 'blue', 'points': 5, 'x_position': 0, 'y_position': 25}
# The enemy is wearing a red shirt.
# Original X position: 0
# New X position: 2
# {'color': 'blue'}
# Meghan loves Pizza.
# 0 points.
# ian
# sever
# 20
# plattsburgh
# {'joe': '1', 'jack': '2', 'john': '3', 'jason': '4', 'jalen': '5'}
# jump - controls the flow of code and alter the normal sequential execution of statements
# run - executing the code
# loop - repeating something over and over until a particular condition is satisfied
# ide - a software application that provides a comprehensive set of features
# compiler - software that translates Python code from human language form into machine code that can be executed directly by a computer
# revision - any change in made in any form to a project
# boolean - a logic that denotes true/false
# commit - to overwrite a previous revision with changes made in a working copy
# ...
